# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets  
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
train = pd.read_csv("C:/Users/SHIVAM/OneDrive/Desktop/Data science Assignment/Naive Basis/SalaryData_Train.csv")

# %%
test = pd.read_csv("C:/Users/SHIVAM/OneDrive/Desktop/Data science Assignment/Naive Basis/SalaryData_Test.csv")

# %%
train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 23433   44          5         12           14              2           3
# 23434   33          2         11            9              5           7
# 23435   51          4         14           15              0           9
# 23436   24          2          8           11              2           6
# 23437   37          4          8           11              4           7
#
#        relationship  race  sex  capitalgain  \
# 0                 1     4    1         2174
# ...

# %%
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23438 entries, 0 to 23437
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            23438 non-null  int64
#  1   workclass      23438 non-null  object
#  2   education      23438 non-null  object
#  3   educationno    23438 non-null  int64
#  4   maritalstatus  23438 non-null  object
#  5   occupation     23438 non-null  object
#  6   relationship   23438 non-null  object
#  7   race           23438 non-null  object
#  8   sex            23438 non-null  object
#  9   capitalgain    23438 non-null  int64
#  10  capitalloss    23437 non-null  float64
#  11  hoursperweek   23437 non-null  float64
#  12  native         23437 non-null  object
#  13  Salary         23437 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 2.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
train = train.drop(23437)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23437 entries, 0 to 23436
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            23437 non-null  int64
#  1   workclass      23437 non-null  object
#  2   education      23437 non-null  object
#  3   educationno    23437 non-null  int64
#  4   maritalstatus  23437 non-null  object
#  5   occupation     23437 non-null  object
#  6   relationship   23437 non-null  object
#  7   race           23437 non-null  object
#  8   sex            23437 non-null  object
#  9   capitalgain    23437 non-null  int64
#  10  capitalloss    23437 non-null  float64
#  11  hoursperweek   23437 non-null  float64
#  12  native         23437 non-null  object
#  13  Salary         23437 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 2.5+ MB

# %%
string_columns = ['workclass','education','maritalstatus','occupation','relationship','race','sex','native','Salary']

# %%
label_encoder = preprocessing.LabelEncoder()
for i in string_columns:
    train[i]=label_encoder.fit_transform(train[i])
    test[i]=label_encoder.fit_transform(test[i])

# %%
train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 23432   51          2         14           15              4           9
# 23433   44          5         12           14              2           3
# 23434   33          2         11            9              5           7
# 23435   51          4         14           15              0           9
# 23436   24          2          8           11              2           6
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
x_train = train.iloc[:,0:13]
y_train = train.iloc[:,-1]
x_test = test.iloc[:,0:13]
y_test = test.iloc[:,-1]

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
x_train = norm_func(x_train)
x_test = norm_func(x_test)

# %%
from sklearn.naive_bayes import MultinomialNB as MB
from sklearn.naive_bayes import GaussianNB as GB

# %% [markdown]
# ## Using Multinomial Naive Bayes

# %%
classifier_mb = MB()
classifier_mb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
classifier_mb.score(x_train,y_train)
# Out:
# 0.7733498314630712

# %%
y_pred = classifier_mb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 77.49667994687915
# array([[10891,   469],
#        [ 2920,   780]], dtype=int64)

# %% [markdown]
# ## Using Gaussian Naive Bayes

# %%
classifier_mb = GB()
classifier_mb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
classifier_mb.score(x_train,y_train)
# Out:
# 0.7964756581473739

# %%
y_pred = classifier_mb.predict(x_test)

# %%
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 79.64143426294821
# array([[10774,   586],
#        [ 2480,  1220]], dtype=int64)
